# %% [markdown]
# # Introduction to Neural Language Models

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# %% [markdown]
# ## Recap of probability chains in language

# %%
import json
from nltk import word_tokenize

# %%
raw_data = '/Users/flint/Data/recipe/recipe1M_layers/layer1.json'
with open(raw_data, 'r') as raw_data_file:
    rdata = json.load(raw_data_file)

# %%
tokenizer = lambda x: ['[sos]'] + word_tokenize(x.lower()) + ['[eos]']
recipe2text = lambda x: " ".join(
    ['[start]'] + 
    [" ".join(tokenizer(y['text'])) for y in rdata[x]['instructions']] + 
    ['[stop]'])

# %%
corpus = [recipe2text(i) for i in range(10**4)]

# %% [markdown]
# ### A different overview of n-gram models

# %%
import networkx as nx
from nltk import ngrams

# %%
def text2graph(recipe, n=2):
    g = nx.DiGraph()
    r = recipe.split()
    for ngram in ngrams(r, n=n, pad_left=True, left_pad_symbol='[pad]'):
        n1, n2 = " ".join(ngram[:-1]), " ".join(ngram[1:])
        g.add_edge(n1, n2)
    return g

# %%
g = text2graph(corpus[0], n=3)

# %%
# Out:
# [pad] [pad] [pad] [start]
# [pad] [start] [start] [sos]
# [start] [sos] [sos] preheat
# [sos] preheat preheat the
# preheat the the oven
# the oven oven to
# the oven oven .
# oven to to 350
# to 350 350 f.
# 350 f. f. butter
# f. butter butter or
# butter or or oil
# or oil oil an
# oil an an 8-inch
# an 8-inch 8-inch baking
# 8-inch baking baking dish
# baking dish dish .
# dish . . [eos]
# . [eos] [eos] [sos]
# . [eos] [eos] [stop]
# [eos] [sos] [sos] cook
# [eos] [sos] [sos] (
# [eos] [sos] [sos] rinse
# [eos] [sos] [sos] combine
# [eos] [sos] [sos] scrape
# [eos] [sos] [sos] sprinkle
# [eos] [sos] [sos] bake
# [eos] [sos] [sos] let
# [eos] [sos] [sos] melt
# [eos] [sos] [sos] continue
# [eos] [sos] [sos] slowly
# [eos] [sos] [sos] remove
# [eos] [sos] [sos] add
# [eos] [sos] [sos] stir
# [eos] [sos] [sos] use
# [eos] [sos] [sos] this
# [eos] [sos] [sos] one-half
# [eos] [sos] [sos] the
# [eos] [sos] [sos] it
# [sos] cook cook the
# [sos] cook cook until
# cook the the penne
# the penne penne 2
# penne 2 2 minutes
# 2 minutes minutes less
# 2 minutes minutes .
# minutes less less than
# less than than package
# than package package directions
# package directions directions .
# directions . . [eos]
# [sos] ( ( it
# ( it it will
# it will will finish
# it will will look
# will finish finish cooking
# finish cooking cooking in
# cooking in in the
# in the the oven
# in the the flour
# oven . . )
# . ) ) [eos]
# ) [eos] [eos] [sos]
# [sos] rinse rinse the
# rinse the the pasta
# the pasta pasta in
# the pasta pasta into
# the pasta pasta ,
# pasta in in cold
# in cold cold water
# cold water water and
# water and and set
# and set set aside
# set aside aside .
# aside . . [eos]
# [sos] combine combine the
# combine the the cooked
# the cooked cooked pasta
# cooked pasta pasta and
# pasta and and the
# and the the sauce
# the sauce sauce in
# the sauce sauce thickens
# the sauce sauce doesnt
# sauce in in a
# in a a medium
# in a a heavy-bottomed
# in a a saucepan
# a medium medium bowl
# medium bowl bowl and
# bowl and and mix
# and mix mix carefully
# mix carefully carefully but
# carefully but but thoroughly
# but thoroughly thoroughly .
# thoroughly . . [eos]
# [sos] scrape scrape the
# scrape the the pasta
# pasta into into the
# into the the prepared
# the prepared prepared baking
# prepared baking baking dish
# [sos] sprinkle sprinkle the
# sprinkle the the top
# the top top with
# top with with the
# with the the cheeses
# the cheeses cheeses and
# the cheeses cheeses ,
# cheeses and and then
# and then then the
# then the the chili
# the chili chili powder
# chili powder powder .
# chili powder powder ,
# chili powder powder makes
# powder . . [eos]
# [sos] bake bake ,
# bake , , uncovered
# , uncovered uncovered ,
# uncovered , , for
# , for for 20
# for 20 20 minutes
# 20 minutes minutes .
# minutes . . [eos]
# [sos] let let the
# let the the mac
# the mac mac and
# mac and and cheese
# and cheese cheese sit
# cheese sit sit for
# sit for for 5
# for 5 5 minutes
# 5 minutes minutes before
# minutes before before serving
# before serving serving .
# serving . . [eos]
# [sos] melt melt the
# melt the the butter
# the butter butter in
# butter in in a
# a heavy-bottomed heavy-bottomed saucepan
# heavy-bottomed saucepan saucepan over
# saucepan over over medium
# saucepan over over low
# over medium medium heat
# medium heat heat and
# heat and and whisk
# and whisk whisk in
# whisk in in the
# the flour flour .
# flour . . [eos]
# [sos] continue continue whisking
# continue whisking whisking and
# whisking and and cooking
# and cooking cooking for
# cooking for for 2
# for 2 2 minutes
# [sos] slowly slowly add
# slowly add add the
# add the the milk
# add the the cheeses
# the milk milk ,
# milk , , whisking
# , whisking whisking constantly
# whisking constantly constantly .
# constantly . . [eos]
# cook until until the
# until the the sauce
# until the the cheese
# sauce thickens thickens ,
# thickens , , about
# , about about 10
# , about about 3
# about 10 10 minutes
# 10 minutes minutes ,
# minutes , , stirring
# , stirring stirring frequently
# stirring frequently frequently .
# frequently . . [eos]
# [sos] remove remove from
# remove from from the
# from the the heat
# the heat heat .
# heat . . [eos]
# [sos] add add the
# cheeses , , salt
# , salt salt ,
# salt , , chili
# , chili chili powder
# powder , , and
# , and and garlic
# and garlic garlic powder
# garlic powder powder .
# [sos] stir stir until
# [sos] stir stir frequently
# stir until until the
# the cheese cheese is
# cheese is is melted
# is melted melted and
# melted and and all
# and all all ingredients
# all ingredients ingredients are
# ingredients are are incorporated
# are incorporated incorporated ,
# incorporated , , about
# about 3 3 minutes
# 3 minutes minutes .
# [sos] use use immediately
# use immediately immediately ,
# immediately , , or
# , or or refrigerate
# or refrigerate refrigerate for
# refrigerate for for up
# for up up to
# up to to 3
# to 3 3 days
# to 3 3 monthsjust
# 3 days days .
# days . . [eos]
# [sos] this this sauce
# [sos] this this recipe
# this sauce sauce reheats
# sauce reheats reheats nicely
# reheats nicely nicely on
# nicely on on the
# on the the stove
# the stove stove in
# stove in in a
# a saucepan saucepan over
# over low low heat
# low heat heat .
# stir frequently frequently so
# frequently so so the
# so the the sauce
# sauce doesnt doesnt scorch
# doesnt scorch scorch .
# scorch . . [eos]
# this recipe recipe can
# recipe can can be
# can be be assembled
# be assembled assembled before
# assembled before before baking
# before baking baking and
# baking and and frozen
# and frozen frozen for
# frozen for for up
# 3 monthsjust monthsjust be
# monthsjust be be sure
# be sure sure to
# sure to to use
# to use use a
# use a a freezer-to-oven
# a freezer-to-oven freezer-to-oven pan
# freezer-to-oven pan pan and
# pan and and increase
# and increase increase the
# increase the the baking
# the baking baking time
# baking time time to
# time to to 50
# to 50 50 minutes
# 50 minutes minutes .
# [sos] one-half one-half teaspoon
# one-half teaspoon teaspoon of
# teaspoon of of chipotle
# of chipotle chipotle chili
# chipotle chili chili powder
# powder makes makes a
# makes a a spicy
# a spicy spicy mac
# spicy mac mac ,
# mac , , so
# , so so make
# so make make sure
# make sure sure your
# sure your your family
# your family family and
# family and and friends
# and friends friends can
# friends can can handle
# can handle handle it
# handle it it !
# it ! ! [eos]
# ! [eos] [eos] [sos]
# [sos] the the proportion
# the proportion proportion of
# proportion of of pasta
# of pasta pasta to
# pasta to to cheese
# to cheese cheese sauce
# cheese sauce sauce is
# sauce is is crucial
# is crucial crucial to
# crucial to to the
# to the the success
# the success success of
# success of of the
# of the the dish
# of the the liquid
# the dish dish .
# [sos] it it will
# will look look like
# look like like a
# like a a lot
# a lot lot of
# lot of of sauce
# of sauce sauce for
# sauce for for the
# for the the pasta
# pasta , , but
# , but but some
# but some some of
# some of of the
# the liquid liquid will
# liquid will will be
# will be be absorbed
# be absorbed absorbed .
# absorbed . . [eos]
