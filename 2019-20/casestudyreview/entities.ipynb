# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
import json

# %%
D = pd.read_csv('../data/yelp_example_1_small.tsv', sep='\t')

# %%
D.head(2)
# Out:
#                                              content  score  \
# 0  This place is WAAAY over priced for the generi...      1
# 1  Our taxi driver had told us to go to this plac...      5
#
#                business  avgstars
# 0          Lee's Buffet       2.0
# 1  Village Pub and Cafe       3.5

# %% [markdown]
# ## Spacy

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = D.loc[1200].content

# %%
print(text)
# Out:
# YESS!
#
# A legit,  24 hour, Pho spot in Vegas that is just a cab ride away from the strip!
#
# Me and my friends came here at 4am after a night out and we were starving!  On a scale of 1 to 10 my level of excitement was 11.  Upon entering, one thing turned me off.  The smell!!  It smelled like they've used the same old, dirty, moldy, rag to wipe down the tables for 100000 years without washing it. The whole restaurant had an old wet towel smell to it.  Regardless, I was still excited to eat.
#
# I ordered the Rare Steak and Brisket Pho  (http:\/\/www.yelp.com\/biz_photos\/pho-kim-long-las-vegas?select=9hI7mkZ4PHU7SjC5hxZqLA#Q1aVULe4TLE41w5R-r7gWg).  The broth was flavorful, refreshing, and not too oily.  The brisket and steak were perfectly cooked and tender.  They gave me a generous amount of noodles too!  Don't forget to ask for the side of sliced onions!  Maybe it's just  a Korean thing and we're trying to make ghetto-kimchi, haha.  (http:\/\/www.yelp.com\/biz_photos\/pho-kim-long-las-vegas?select=9hI7mkZ4PHU7SjC5hxZqLA#osrvZk6r45zRC0stiCZ0tQ)
#
# I wouldn't recommend the chicken pho... I tried my friend's chicken pho and it just tasted like salty water-- where's the chicken flavor hmmm?

# %%
for ent in nlp(text).ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# 24 hour 19 26 TIME
# Pho 28 31 GPE
# Vegas 40 45 GPE
# 4am after a night 123 140 TIME
# 1 182 183 CARDINAL
# 10 187 189 CARDINAL
# 11 217 219 CARDINAL
# one 237 240 CARDINAL
# 100000 years 365 377 DATE
# the Rare Steak 506 520 WORK_OF_ART
# Korean 885 891 NORP

# %% [markdown]
# ## TextRazor

# %%
import textrazor

# %%
def topics_entities(doc_id, text, client):
    entities, topics = [], []
    try:
        response = client.analyze(text)
        for entity in response.entities():
            E = {'id': entity.id, 'relevance': entity.relevance_score, 
                 'confidence': entity.confidence_score, 
                 'dbpedia_types': entity.dbpedia_types, 
                 'wikipedia': entity.wikipedia_link,
                 'matched_text': entity.matched_text, 
                 'matched_words': entity.matched_words,
                 'doc_id': doc_id
                }
            entities.append(E)
        for topic in response.topics():
            T = {'wikidata': topic.wikidata_id, 
                 'wikipedia': topic.wikipedia_link, 
                 'score': topic.score, 'label': topic.label,
                 'doc_id': doc_id
                }
            topics.append(T)
    except:
        pass
    return entities, topics

# %%
with open('../data/keys.json', 'r') as infile:
    k = json.load(infile)

# %%
textrazor.api_key = k['razor']

client = textrazor.TextRazor(extractors=["entities", "topics"])

e, t = topics_entities(1, text, client)

# %%
t
# Out:
# [{'wikidata': 'Q420646',
#   'wikipedia': 'http://en.wikipedia.org/Pho',
#   'score': 1,
#   'label': 'Pho',
#   'doc_id': 1},
#  {'wikidata': 'Q1778821',
#   'wikipedia': 'http://en.wikipedia.org/Category:Cuisine',
#   'score': 1,
#   'label': 'Cuisine',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Ancient_dishes',
#   'score': 1,
#   'label': 'Ancient dishes',
#   'doc_id': 1},
#  {'wikidata': 'Q10675206',
#   'wikipedia': 'http://en.wikipedia.org/Category:Food_ingredients',
#   'score': 1,
#   'label': 'Food ingredients',
#   'doc_id': 1},
#  {'wikidata': 'Q192628',
#   'wikipedia': 'http://en.wikipedia.org/Category:Beef',
#   'score': 1,
#   'label': 'Beef',
#   'doc_id': 1},
#  {'wikidata': 'Q1427844',
#   'wikipedia': 'http://en.wikipedia.org/Category:Meat_dishes',
#   'score': 1,
#   'label': 'Meat dishes',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Prepared_foods_by_main_ingredient',
#   'score': 1,
#   'label': 'Prepared foods',
#   'doc_id': 1},
#  {'wikidata': 'Q728206',
#   'wikipedia': 'http://en.wikipedia.org/Category:Asian_cuisine',
#   'score': 1,
#   'label': 'Asian cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q38695',
#   'wikipedia': 'http://en.wikipedia.org/Category:Cooking',
#   'score': 1,
#   'label': 'Cooking',
#   'doc_id': 1},
#  {'wikidata': 'Q10990',
#   'wikipedia': 'http://en.wikipedia.org/Category:Meat',
#   'score': 1,
#   'label': 'Meat',
#   'doc_id': 1},
#  {'wikidata': 'Q2095',
#   'wikipedia': 'http://en.wikipedia.org/Category:Foods',
#   'score': 1,
#   'label': 'Foods',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Food_and_drink_preparation',
#   'score': 1,
#   'label': 'Food and drink preparation',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Western_cuisine',
#   'score': 1,
#   'label': 'Western cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q951964',
#   'wikipedia': 'http://en.wikipedia.org/Category:Food_and_drink',
#   'score': 1,
#   'label': 'Food and drink',
#   'doc_id': 1},
#  {'wikidata': 'Q192874',
#   'wikipedia': 'http://en.wikipedia.org/Category:Noodles',
#   'score': 1,
#   'label': 'Noodles',
#   'doc_id': 1},
#  {'wikidata': 'Q41415',
#   'wikipedia': 'http://en.wikipedia.org/Category:Soups',
#   'score': 1,
#   'label': 'Soups',
#   'doc_id': 1},
#  {'wikidata': 'Q28100368',
#   'wikipedia': 'http://en.wikipedia.org/Category:Beef_dishes',
#   'score': 1,
#   'label': 'Beef dishes',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Noodle_dishes',
#   'score': 1,
#   'label': 'Noodle dishes',
#   'doc_id': 1},
#  {'wikidata': 'Q4120078',
#   'wikipedia': 'http://en.wikipedia.org/Category:North_American_cuisine',
#   'score': 0.9896,
#   'label': 'North American cuisine',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Cattle_products',
#   'score': 0.9803,
#   'label': 'Cattle products',
#   'doc_id': 1},
#  {'wikidata': 'Q579316',
#   'wikipedia': 'http://en.wikipedia.org/Category:European_cuisine',
#   'score': 0.9519,
#   'label': 'European cuisine',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Soups_and_stews',
#   'score': 0.9334,
#   'label': 'Soups and stews',
#   'doc_id': 1},
#  {'wikidata': 'Q629103',
#   'wikipedia': 'http://en.wikipedia.org/Category:Animal_products',
#   'score': 0.9316,
#   'label': 'Animal products',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Animal_death',
#   'score': 0.9031,
#   'label': 'Animal death',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:World_cuisine',
#   'score': 0.8963,
#   'label': 'World cuisine',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Noodle_soups',
#   'score': 0.8933,
#   'label': 'Noodle soups',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Eating_behaviors_of_humans',
#   'score': 0.882,
#   'label': 'Eating behaviors of humans',
#   'doc_id': 1},
#  {'wikidata': 'Q540912',
#   'wikipedia': 'http://en.wikipedia.org/Category:Food_industry',
#   'score': 0.8426,
#   'label': 'Food industry',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Southeast_Asian_cuisine',
#   'score': 0.8177,
#   'label': 'Southeast Asian cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q736427',
#   'wikipedia': 'http://en.wikipedia.org/Category:Staple_foods',
#   'score': 0.7659,
#   'label': 'Staple foods',
#   'doc_id': 1},
#  {'wikidata': 'Q1324342',
#   'wikipedia': 'http://en.wikipedia.org/Brisket',
#   'score': 0.7417,
#   'label': 'Brisket',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:East_Asian_cuisine',
#   'score': 0.7301,
#   'label': 'East Asian cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q40578',
#   'wikipedia': 'http://en.wikipedia.org/Category:American_cuisine',
#   'score': 0.7263,
#   'label': 'American cuisine',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Vietnamese_fusion_cuisine',
#   'score': 0.6895,
#   'label': 'Vietnamese fusion cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q213062',
#   'wikipedia': 'http://en.wikipedia.org/Steak',
#   'score': 0.6841,
#   'label': 'Steak',
#   'doc_id': 1},
#  {'wikidata': 'Q38695',
#   'wikipedia': 'http://en.wikipedia.org/Category:Cooking_techniques',
#   'score': 0.6799,
#   'label': 'Cooking techniques',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:National_dishes',
#   'score': 0.669,
#   'label': 'National dishes',
#   'doc_id': 1},
#  {'wikidata': 'Q864693',
#   'wikipedia': 'http://en.wikipedia.org/Chicken_as_food',
#   'score': 0.6659,
#   'label': 'Chicken as food',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Vietnamese_noodle_dishes',
#   'score': 0.6593,
#   'label': 'Vietnamese noodle dishes',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:French_fusion_cuisine',
#   'score': 0.6554,
#   'label': 'French fusion cuisine',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Vietnamese_soups',
#   'score': 0.6162,
#   'label': 'Vietnamese soups',
#   'doc_id': 1},
#  {'wikidata': 'Q461696',
#   'wikipedia': 'http://en.wikipedia.org/Category:Barbecue',
#   'score': 0.6159,
#   'label': 'Barbecue',
#   'doc_id': 1},
#  {'wikidata': 'Q7928657',
#   'wikipedia': 'http://en.wikipedia.org/Category:Vietnamese_noodles',
#   'score': 0.5977,
#   'label': 'Vietnamese noodles',
#   'doc_id': 1},
#  {'wikidata': 'Q826059',
#   'wikipedia': 'http://en.wikipedia.org/Category:Vietnamese_cuisine',
#   'score': 0.588,
#   'label': 'Vietnamese cuisine',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Vietnamese-American_cuisine',
#   'score': 0.5745,
#   'label': 'Vietnamese-American cuisine',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Asian-American_cuisine',
#   'score': 0.5676,
#   'label': 'Asian-American cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q81799',
#   'wikipedia': 'http://en.wikipedia.org/Category:Fast_food',
#   'score': 0.562,
#   'label': 'Fast food',
#   'doc_id': 1},
#  {'wikidata': 'Q13485782',
#   'wikipedia': 'http://en.wikipedia.org/Category:Convenience_foods',
#   'score': 0.5536,
#   'label': 'Convenience foods',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Vietnamese_words_and_phrases',
#   'score': 0.5468,
#   'label': 'Vietnamese words and phrases',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Food_retailing',
#   'score': 0.5421,
#   'label': 'Food retailing',
#   'doc_id': 1},
#  {'wikidata': 'Q601763',
#   'wikipedia': 'http://en.wikipedia.org/Category:Fusion_cuisine',
#   'score': 0.5407,
#   'label': 'Fusion cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q16920758',
#   'wikipedia': 'http://en.wikipedia.org/Category:Food_preparation',
#   'score': 0.5265,
#   'label': 'Food preparation',
#   'doc_id': 1},
#  {'wikidata': 'Q934309',
#   'wikipedia': 'http://en.wikipedia.org/Category:Mediterranean_cuisine',
#   'score': 0.524,
#   'label': 'Mediterranean cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q386284',
#   'wikipedia': 'http://en.wikipedia.org/Category:African_cuisine',
#   'score': 0.5237,
#   'label': 'African cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q1547037',
#   'wikipedia': 'http://en.wikipedia.org/Category:Middle_Eastern_cuisine',
#   'score': 0.5125,
#   'label': 'Middle Eastern cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q468817',
#   'wikipedia': 'http://en.wikipedia.org/Category:Cuisine_of_the_Americas',
#   'score': 0.4894,
#   'label': 'Cuisine of the Americas',
#   'doc_id': 1},
#  {'wikidata': 'Q103459',
#   'wikipedia': 'http://en.wikipedia.org/Category:Livestock',
#   'score': 0.4341,
#   'label': 'Livestock',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Street_vendors',
#   'score': 0.4252,
#   'label': 'Street vendors',
#   'doc_id': 1},
#  {'wikidata': 'Q6418247',
#   'wikipedia': 'http://en.wikipedia.org/Category:Cuts_of_meat',
#   'score': 0.4085,
#   'label': 'Cuts of meat',
#   'doc_id': 1},
#  {'wikidata': 'Q1316209',
#   'wikipedia': 'http://en.wikipedia.org/Category:Street_food',
#   'score': 0.3937,
#   'label': 'Street food',
#   'doc_id': 1},
#  {'wikidata': 'Q2695280',
#   'wikipedia': 'http://en.wikipedia.org/Category:Techniques',
#   'score': 0.3831,
#   'label': 'Techniques',
#   'doc_id': 1},
#  {'wikidata': 'Q11707',
#   'wikipedia': 'http://en.wikipedia.org/Restaurant',
#   'score': 0.3805,
#   'label': 'Restaurant',
#   'doc_id': 1},
#  {'wikidata': 'Q27477249',
#   'wikipedia': 'http://en.wikipedia.org/Category:Chinese_cuisine',
#   'score': 0.3741,
#   'label': 'Chinese cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q881',
#   'wikipedia': 'http://en.wikipedia.org/Category:Vietnam',
#   'score': 0.3692,
#   'label': 'Vietnam',
#   'doc_id': 1},
#  {'wikidata': 'Q1128637',
#   'wikipedia': 'http://en.wikipedia.org/Category:National_symbols',
#   'score': 0.3576,
#   'label': 'National symbols',
#   'doc_id': 1},
#  {'wikidata': 'Q7743',
#   'wikipedia': 'http://en.wikipedia.org/Category:Home',
#   'score': 0.3489,
#   'label': 'Home',
#   'doc_id': 1},
#  {'wikidata': 'Q191768',
#   'wikipedia': 'http://en.wikipedia.org/Category:Pork',
#   'score': 0.3231,
#   'label': 'Pork',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Lifestyles',
#   'score': 0.3224,
#   'label': 'Lifestyles',
#   'doc_id': 1},
#  {'wikidata': 'Q28100020',
#   'wikipedia': 'http://en.wikipedia.org/Category:Pork_dishes',
#   'score': 0.3215,
#   'label': 'Pork dishes',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:American_fusion_cuisine',
#   'score': 0.321,
#   'label': 'American fusion cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q275068',
#   'wikipedia': 'http://en.wikipedia.org/Broth',
#   'score': 0.3143,
#   'label': 'Broth',
#   'doc_id': 1},
#  {'wikidata': 'Q6661',
#   'wikipedia': 'http://en.wikipedia.org/Category:French_cuisine',
#   'score': 0.3045,
#   'label': 'French cuisine',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Cuts_of_beef',
#   'score': 0.3016,
#   'label': 'Cuts of beef',
#   'doc_id': 1},
#  {'wikidata': 'Q2233666',
#   'wikipedia': 'http://en.wikipedia.org/Category:Vietnamese_diaspora',
#   'score': 0.2986,
#   'label': 'Vietnamese diaspora',
#   'doc_id': 1},
#  {'wikidata': 'Q47728',
#   'wikipedia': 'http://en.wikipedia.org/Category:Hobbies',
#   'score': 0.2964,
#   'label': 'Hobbies',
#   'doc_id': 1},
#  {'wikidata': 'Q7884093',
#   'wikipedia': 'http://en.wikipedia.org/Category:Home_economics',
#   'score': 0.2828,
#   'label': 'Home economics',
#   'doc_id': 1},
#  {'wikidata': 'Q178559',
#   'wikipedia': 'http://en.wikipedia.org/Category:Poultry',
#   'score': 0.2785,
#   'label': 'Poultry',
#   'doc_id': 1},
#  {'wikidata': 'Q4282505',
#   'wikipedia': 'http://en.wikipedia.org/Category:Meat_industry',
#   'score': 0.2754,
#   'label': 'Meat industry',
#   'doc_id': 1},
#  {'wikidata': 'Q23485',
#   'wikipedia': 'http://en.wikipedia.org/Onion',
#   'score': 0.2695,
#   'label': 'Onion',
#   'doc_id': 1},
#  {'wikidata': 'Q2657969',
#   'wikipedia': 'http://en.wikipedia.org/Category:Vietnamese_American',
#   'score': 0.2682,
#   'label': 'Vietnamese American',
#   'doc_id': 1},
#  {'wikidata': 'Q780',
#   'wikipedia': 'http://en.wikipedia.org/Category:Chickens',
#   'score': 0.2622,
#   'label': 'Chickens',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Domesticated_birds',
#   'score': 0.2424,
#   'label': 'Domesticated birds',
#   'doc_id': 1},
#  {'wikidata': 'Q2723400',
#   'wikipedia': 'http://en.wikipedia.org/Category:Chinese_noodles',
#   'score': 0.2154,
#   'label': 'Chinese noodles',
#   'doc_id': 1},
#  {'wikidata': 'Q11619980',
#   'wikipedia': 'http://en.wikipedia.org/Category:Regional_cuisines_of_China',
#   'score': 0.2096,
#   'label': 'Regional cuisines of China',
#   'doc_id': 1},
#  {'wikidata': 'Q11559422',
#   'wikipedia': 'http://en.wikipedia.org/Category:Seafood_dishes',
#   'score': 0.2076,
#   'label': 'Seafood dishes',
#   'doc_id': 1},
#  {'wikidata': 'Q18679149',
#   'wikipedia': 'http://en.wikipedia.org/Category:Fish_dishes',
#   'score': 0.2019,
#   'label': 'Fish dishes',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Animals_and_humans',
#   'score': 0.19,
#   'label': 'Animals and humans',
#   'doc_id': 1},
#  {'wikidata': 'Q11042',
#   'wikipedia': 'http://en.wikipedia.org/Category:Culture',
#   'score': 0.1851,
#   'label': 'Culture',
#   'doc_id': 1},
#  {'wikidata': 'Q171141',
#   'wikipedia': 'http://en.wikipedia.org/Category:Gastronomy',
#   'score': 0.177,
#   'label': 'Gastronomy',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Dining',
#   'score': 0.1752,
#   'label': 'Dining',
#   'doc_id': 1},
#  {'wikidata': 'Q18697490',
#   'wikipedia': 'http://en.wikipedia.org/Category:Lamb_dishes',
#   'score': 0.1741,
#   'label': 'Lamb dishes',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Primary_industries',
#   'score': 0.1708,
#   'label': 'Primary industries',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Chinese_noodle_dishes',
#   'score': 0.158,
#   'label': 'Chinese noodle dishes',
#   'doc_id': 1},
#  {'wikidata': 'Q622852',
#   'wikipedia': 'http://en.wikipedia.org/Category:Domesticated_animals',
#   'score': 0.1509,
#   'label': 'Domesticated animals',
#   'doc_id': 1},
#  {'wikidata': 'Q2481478',
#   'wikipedia': 'http://en.wikipedia.org/Category:Aviculture',
#   'score': 0.1397,
#   'label': 'Aviculture',
#   'doc_id': 1},
#  {'wikidata': 'Q11707',
#   'wikipedia': 'http://en.wikipedia.org/Category:Restaurants',
#   'score': 0.1376,
#   'label': 'Restaurants',
#   'doc_id': 1},
#  {'wikidata': 'Q192874',
#   'wikipedia': 'http://en.wikipedia.org/Noodle',
#   'score': 0.1335,
#   'label': 'Noodle',
#   'doc_id': 1},
#  {'wikidata': 'Q234138',
#   'wikipedia': 'http://en.wikipedia.org/Category:Japanese_cuisine',
#   'score': 0.1322,
#   'label': 'Japanese cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q600396',
#   'wikipedia': 'http://en.wikipedia.org/Category:Edible_fish',
#   'score': 0.132,
#   'label': 'Edible fish',
#   'doc_id': 1},
#  {'wikidata': 'Q647500',
#   'wikipedia': 'http://en.wikipedia.org/Category:Korean_cuisine',
#   'score': 0.1177,
#   'label': 'Korean cuisine',
#   'doc_id': 1},
#  {'wikidata': 'Q12147',
#   'wikipedia': 'http://en.wikipedia.org/Category:Health',
#   'score': 0.1167,
#   'label': 'Health',
#   'doc_id': 1},
#  {'wikidata': 'Q18097',
#   'wikipedia': 'http://en.wikipedia.org/Korea',
#   'score': 0.1097,
#   'label': 'Korea',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Food_and_drink_companies',
#   'score': 0.08252,
#   'label': 'Food and drink companies',
#   'doc_id': 1},
#  {'wikidata': 'Q1495452',
#   'wikipedia': 'http://en.wikipedia.org/Category:Hospitality_industry',
#   'score': 0.0821,
#   'label': 'Hospitality industry',
#   'doc_id': 1},
#  {'wikidata': 'Q268592',
#   'wikipedia': 'http://en.wikipedia.org/Category:Industries',
#   'score': 0.0777,
#   'label': 'Industries',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Food_retailers',
#   'score': 0.06519,
#   'label': 'Food retailers',
#   'doc_id': 1},
#  {'wikidata': 'Q638022',
#   'wikipedia': 'http://en.wikipedia.org/Category:Vegetarian_cuisine',
#   'score': 0.05941,
#   'label': 'Vegetarian cuisine',
#   'doc_id': 1},
#  {'wikidata': None,
#   'wikipedia': 'http://en.wikipedia.org/Category:Food-_and_drink-related_organizations',
#   'score': 0.05508,
#   'label': 'Food- and drink-related organizations',
#   'doc_id': 1}]

# %% [markdown]
# ## IBM watson

# %%
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions
from ibm_watson.natural_language_understanding_v1 import ConceptsOptions, SentimentOptions
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
with open('../data/keys.json', 'r') as infile:
    k = json.load(infile)

# %%
authenticator = IAMAuthenticator(k['watson'])
service = NaturalLanguageUnderstandingV1(version='2018-03-16', authenticator=authenticator)
service.set_service_url('https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/b09de8e9-644f-45d5-9f53-65c51aed0524')

# %%
response = service.analyze(
            text=text, features=Features(
                entities=EntitiesOptions(sentiment=True),
                concepts=ConceptsOptions(),
                sentiment=SentimentOptions())).get_result()

# %%
response
# Out:
# {'usage': {'text_units': 1, 'text_characters': 1202, 'features': 3},
#  'sentiment': {'document': {'score': 0.458612, 'label': 'positive'}},
#  'language': 'en',
#  'entities': [{'type': 'Location',
#    'text': 'Vegas',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.790891,
#    'disambiguation': {'subtype': ['City']},
#    'count': 1},
#   {'type': 'Quantity',
#    'text': '100000 years',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.790891,
#    'count': 1},
#   {'type': 'Quantity',
#    'text': '24 hour',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.790891,
#    'count': 1}],
#  'concepts': [{'text': 'Taste',
#    'relevance': 0.942114,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Taste'},
#   {'text': 'Water',
#    'relevance': 0.922209,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Water'},
#   {'text': 'Steak',
#    'relevance': 0.808267,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Steak'},
#   {'text': '2005 singles',
#    'relevance': 0.765707,
#    'dbpedia_resource': 'http://dbpedia.org/resource/2005_singles'},
#   {'text': 'Friends',
#    'relevance': 0.688796,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Friends'},
#   {'text': 'Friendship',
#    'relevance': 0.688686,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Friendship'},
#   {'text': 'Phở',
#    'relevance': 0.68,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Phở'},
#   {'text': 'Strip steak',
#    'relevance': 0.678163,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Strip_steak'}]}
